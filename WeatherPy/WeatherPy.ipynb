# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['tuatapere',
#  'manokwari',
#  'sitka',
#  'butterworth',
#  'vaini',
#  'cape town',
#  'nikolskoye',
#  'sokone',
#  'busselton',
#  'chantada',
#  'grand river south east',
#  'kaseda',
#  'rikitea',
#  'brownwood',
#  'byron bay',
#  'hualmay',
#  'mahon',
#  'taolanaro',
#  'bredasdorp',
#  'mitsamiouli',
#  'torbay',
#  'castro',
#  'acapulco',
#  'lompoc',
#  'linchuan',
#  'gobabis',
#  'lalibela',
#  'hithadhoo',
#  'cabra',
#  'coquimbo',
#  'orangeville',
#  'aykhal',
#  'ushuaia',
#  'ponta do sol',
#  'albany',
#  'upernavik',
#  'pacific grove',
#  'chuy',
#  'hambantota',
#  'tuktoyaktuk',
#  'bengkulu',
#  'ocos',
#  'lata',
#  'beipiao',
#  'ust-nera',
#  'northam',
#  'same',
#  'batagay-alyta',
#  'tari',
#  'qaanaaq',
#  'otavi',
#  'utinga',
#  'puerto del rosario',
#  'sampit',
#  'punta arenas',
#  'ponta delgada',
#  'mataura',
#  'comodoro rivadavia',
#  'puerto ayora',
#  'kapaa',
#  'karpathos',
#  'balclutha',
#  'bluff',
#  'amderma',
#  'atuona',
#  'ancud',
#  'dwarka',
#  'launceston',
#  'belushya guba',
#  'ribeira grande',
#  'akom',
#  'avarua',
#  'urumqi',
#  'provideniya',
#  'ajdabiya',
#  'port lincoln',
#  'barrow',
#  'rawson',
#  'east london',
#  'chokurdakh',
#  'atambua',
#  'taft',
#  'codrington',
#  'hami',
#  'dikson',
#  'nizhneyansk',
#  'mahebourg',
#  'cabo san lucas',
#  'saint-pierre',
#  'thompson',
#  'westport',
#  'tiksi',
#  'vila velha',
#  'souillac',
#  'peniche',
#  'arraial do cabo',
#  'bandarbeyla',
#  'taitung',
#  'sevilla',
#  'padang',
#  'tasiilaq',
#  'tsabong',
#  'faya',
#  'ostrovnoy',
#  'jamestown',
#  'cherskiy',
#  'guerrero negro',
#  'bonavista',
#  'batavia',
#  'port alfred',
#  'kismayo',
#  'basoko',
#  'goure',
#  'umzimvubu',
#  'namatanai',
#  'new norfolk',
#  'attawapiskat',
#  'yulara',
#  'hilo',
#  'yellowknife',
#  'butaritari',
#  'juifang',
#  'rongcheng',
#  'atar',
#  'thinadhoo',
#  'khatanga',
#  'iqaluit',
#  'avera',
#  'faanui',
#  'constitucion',
#  'katherine',
#  'narsaq',
#  'abonnema',
#  'bethel',
#  'mayo',
#  'tukrah',
#  'okakarara',
#  'illoqqortoormiut',
#  'biak',
#  'barentsburg',
#  'sola',
#  'luderitz',
#  'salalah',
#  'benemerito de las americas',
#  'vila',
#  'bara',
#  'lavrentiya',
#  'fort-shevchenko',
#  'areosa',
#  'nara',
#  'lagoa',
#  'tautira',
#  'saskylakh',
#  'port elizabeth',
#  'berezovyy',
#  'along',
#  'urucara',
#  'vostok',
#  'saint-philippe',
#  'sulangan',
#  'cascais',
#  'yerbogachen',
#  'culebra',
#  'jatai',
#  'kiruna',
#  'georgetown',
#  'fortuna',
#  'olafsvik',
#  'creston',
#  'puerto quijarro',
#  'nanortalik',
#  'iskateley',
#  'hovd',
#  'mar del plata',
#  'kavieng',
#  'port-gentil',
#  'hermanus',
#  'saint george',
#  'harper',
#  'kisangani',
#  'salekhard',
#  'quatre cocos',
#  'grindavik',
#  'hobart',
#  'kutum',
#  'cumaribo',
#  'taltal',
#  'neiafu',
#  'cidreira',
#  'taoudenni',
#  'pisco',
#  'dedza',
#  'newberry',
#  'sao filipe',
#  'devils lake',
#  'sentyabrskiy',
#  'margate',
#  'colares',
#  'esperance',
#  'henties bay',
#  'bijie',
#  'college',
#  'rundu',
#  'nouadhibou',
#  'weligama',
#  'san patricio',
#  'concordia',
#  'muli',
#  'khasan',
#  'dudinka',
#  'tura',
#  'flin flon',
#  'santiago del estero',
#  'tessaoua',
#  'dondo',
#  'athabasca',
#  'sakakah',
#  'tshikapa',
#  'behshahr',
#  'vardo',
#  'kloulklubed',
#  'nguiu',
#  'aksu',
#  'severo-kurilsk',
#  'victoria',
#  'kodiak',
#  'waipawa',
#  'guaratinga',
#  'walvis bay',
#  'yurya',
#  'stanger',
#  'lorengau',
#  'jalor',
#  'blagoyevo',
#  'cabedelo',
#  'poum',
#  'marcona',
#  'hofn',
#  'aklavik',
#  'rock sound',
#  'punta alta',
#  'sao joao da ponte',
#  'lunglei',
#  'qeshm',
#  'swinoujscie',
#  'olinda',
#  'saint anthony',
#  'perth',
#  'clyde river',
#  'haapiti',
#  'honningsvag',
#  'haines junction',
#  'kruisfontein',
#  'fairfield',
#  'raudeberg',
#  'shimoda',
#  'beyla',
#  'teahupoo',
#  'canavieiras',
#  'ahipara',
#  'marsh harbour',
#  'maumere',
#  'sydney',
#  'canete',
#  'bereda',
#  'san andres',
#  'nerchinskiy zavod',
#  'caravelas',
#  'alofi',
#  'pandan',
#  'nichinan',
#  'jahazpur',
#  'san luis',
#  'tarko-sale',
#  'guatire',
#  'carnarvon',
#  'lugovoy',
#  'mmabatho',
#  'persianovskiy',
#  'porto novo',
#  'tsihombe',
#  'isangel',
#  'kaitangata',
#  'beringovskiy',
#  'nalut',
#  'port moresby',
#  'mullaitivu',
#  'paamiut',
#  'nome',
#  'naini tal',
#  'bowen',
#  'pimentel',
#  'mys shmidta',
#  'koumra',
#  'sao joao da barra',
#  'baykit',
#  'lebu',
#  'escanaba',
#  'cortes',
#  'pitea',
#  'petropavlovsk-kamchatskiy',
#  'emerald',
#  'saleaula',
#  'ust-maya',
#  'vao',
#  'zyryanka',
#  'portland',
#  'aden',
#  'avdiyivka',
#  'butembo',
#  'nishihara',
#  'karauzyak',
#  'montreal',
#  'lewisporte',
#  'xiamen',
#  'zyukayka',
#  'srandakan',
#  'broken hill',
#  'isla mujeres',
#  'lubao',
#  'oltina',
#  'huarmey',
#  'montego bay',
#  'termiz',
#  'kamenskoye',
#  'tezu',
#  'guilin',
#  'lolua',
#  'falealupo',
#  'garowe',
#  'isfana',
#  'sorland',
#  'pijijiapan',
#  'san francisco',
#  'bela vista de goias',
#  'waterloo',
#  'voh',
#  'vestmannaeyjar',
#  'sokolo',
#  'paso de los toros',
#  'banepa',
#  'sao felix do xingu',
#  'vaitupu',
#  'smidovich',
#  'laguna',
#  'gubkinskiy',
#  'san cristobal',
#  'shumskiy',
#  'mae hong son',
#  'marienburg',
#  'mehamn',
#  'nirasaki',
#  'kirakira',
#  'alexandria',
#  'makaha',
#  'pangkalanbuun',
#  'resende',
#  'uwayl',
#  'nanchang',
#  'key west',
#  'satitoa',
#  'geraldton',
#  'cefalu',
#  'kongolo',
#  'miyako',
#  'muros',
#  'vila franca do campo',
#  'posadas',
#  'mnogovershinnyy',
#  'saint-augustin',
#  'ternova',
#  'vega de alatorre',
#  'maxixe',
#  'langfang',
#  'talnakh',
#  'saldanha',
#  'banjarmasin',
#  'plouzane',
#  'tabou',
#  'taybad',
#  'saint marys',
#  'san carlos de bariloche',
#  'namibe',
#  'balsas',
#  'ardrishaig',
#  'betsiamites',
#  'bandundu',
#  'fare',
#  'camacha',
#  'san quintin',
#  'jalu',
#  'longyearbyen',
#  'bambous virieux',
#  'stephenville',
#  'jiddah',
#  'contamana',
#  'bonoua',
#  'uruzgan',
#  'disa',
#  'los llanos de aridane',
#  'rassvet',
#  'boa vista',
#  'andros town',
#  'prince rupert',
#  'totoro',
#  'ayan',
#  'pathalgaon',
#  'maralal',
#  'pokhara',
#  'bathsheba',
#  'itaituba',
#  'zachagansk',
#  'bud',
#  'kaiyuan',
#  'te anau',
#  'yaan',
#  'vilyuysk',
#  'seshcha',
#  'asau',
#  'sarankhola',
#  'slave lake',
#  'hamilton',
#  'narrabri',
#  'bolshiye berezniki',
#  'kapit',
#  'pedernales',
#  'biu',
#  'adolfo lopez mateos',
#  'mizan teferi',
#  'sambava',
#  'rabo de peixe',
#  'kinel-cherkassy',
#  'tucurui',
#  'almetyevsk',
#  'yerkoy',
#  'flinders',
#  'ulyanovka',
#  'long beach',
#  'dicabisagan',
#  'puerto colombia',
#  'cedar rapids',
#  'viedma',
#  'rockwall',
#  'adrar',
#  'nizhniy kuranakh',
#  'berlevag',
#  'somogyvar',
#  'muravlenko',
#  'richards bay',
#  'namuac',
#  'anadyr',
#  'susurluk',
#  'moree',
#  'saurimo',
#  'kropotkin',
#  'koulikoro',
#  'coihaique',
#  'fuerte',
#  'puro',
#  'sioux lookout',
#  'natal',
#  'meulaboh',
#  'crab hill',
#  'dong hoi',
#  'chifeng',
#  'drovyanaya',
#  'norman wells',
#  'guhagar',
#  'ginir',
#  'aksarka',
#  'pelym',
#  'tubruq',
#  'seymchan',
#  'komsomolskiy',
#  'rocha',
#  'tumannyy',
#  'gondanglegi',
#  'munai',
#  'rafraf',
#  'nelson bay',
#  'guozhen',
#  'bartica',
#  'oranjemund',
#  'araouane',
#  'vondrozo',
#  'phangnga',
#  'ondorhaan',
#  'socorro',
#  'egvekinot',
#  'kajaani',
#  'iglino',
#  'yambio',
#  'jizan',
#  'u thong',
#  'boralday',
#  'high level',
#  'todos santos',
#  'luwuk',
#  'bobcaygeon',
#  'novobirilyussy',
#  'chagda',
#  'sur',
#  'coruripe',
#  'kokkinion',
#  'cap malheureux',
#  'kahului',
#  'bundaberg',
#  'muisne',
#  'saryagash',
#  'durban',
#  'warqla',
#  'hefei',
#  'mookane',
#  'kawana waters',
#  'grand island',
#  'matara',
#  'baruun-urt',
#  'raychikhinsk',
#  'ilulissat',
#  'phan thiet',
#  'pula',
#  'vanavara',
#  'balkhash',
#  'nioro',
#  'indramayu',
#  'broome',
#  'pangnirtung',
#  'yining',
#  'bama',
#  'belmonte',
#  'charlestown',
#  'kaeo',
#  'tokur',
#  'piacabucu',
#  'pevek',
#  'dunda',
#  'magui',
#  'babanusah',
#  'tevriz',
#  'kushmurun',
#  'ambon',
#  'kupang',
#  'hoa binh',
#  'bardiyah',
#  'labuhan',
#  'ilheus',
#  'ibague',
#  'cockburn harbour',
#  'haysville',
#  'wesselsbron',
#  'ouesso',
#  'dargaville',
#  'dolbeau',
#  'coos bay',
#  'hasaki',
#  'lev tolstoy',
#  'lethem',
#  'teya',
#  'belyy yar',
#  'ngunguru',
#  'natchitoches',
#  'saint-leu',
#  'bairiki',
#  'denpasar',
#  'sorkjosen',
#  'malanday',
#  'horasan',
#  'ashqelon',
#  'tatarsk',
#  'adamovka',
#  'yokadouma',
#  'kiama',
#  'benguela',
#  'nurota',
#  'bonthe',
#  'xiaoweizhai',
#  'kumluca',
#  'wanaka',
#  'sao gabriel da cachoeira',
#  'erenhot',
#  'shizunai',
#  'sfantu gheorghe',
#  'chicama',
#  'wuzhou',
#  'takoradi',
#  'kungurtug',
#  'iquique',
#  'freeport',
#  'chara',
#  'sovetskiy',
#  'rovira',
#  'west monroe',
#  'leningradskiy',
#  'laibin',
#  'xai-xai',
#  'gat',
#  'ilhabela',
#  'kampene',
#  'oistins',
#  'buenos aires',
#  'tadine',
#  'suoyarvi',
#  'obluche',
#  'sembe',
#  'savasleyka',
#  'helong',
#  'ivankiv',
#  'nemuro',
#  'houma',
#  'marawi',
#  'barabai',
#  'zhezkazgan',
#  'husavik',
#  'nerang',
#  'kamiiso',
#  'golkoy',
#  'troitsko-pechorsk',
#  'saryshagan',
#  'mogadishu',
#  'nogales',
#  'gambela',
#  'vite',
#  'la romana',
#  'ao luk',
#  'san vicente',
#  'inta',
#  'praia da vitoria',
#  'khairpur nathan shah',
#  'katsuura',
#  'linxia',
#  'formosa do rio preto']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""     
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""
weather_df["Date"] = "" 


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + '&units='+ units + "&q=" + city 
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = weather_response["dt"]
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = weather_response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | tuatapere.
# Processing Record 1  of Set 1 | manokwari.
# Processing Record 2  of Set 1 | sitka.
# Processing Record 3  of Set 1 | butterworth.
# Processing Record 4  of Set 1 | vaini.
# Processing Record 5  of Set 1 | cape town.
# Processing Record 6  of Set 1 | nikolskoye.
# Processing Record 7  of Set 1 | sokone.
# Processing Record 8  of Set 1 | busselton.
# Processing Record 9  of Set 1 | chantada.
# Processing Record 10  of Set 1 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 11  of Set 1 | kaseda.
# Processing Record 12  of Set 1 | rikitea.
# Processing Record 13  of Set 1 | brownwood.
# Processing Record 14  of Set 1 | byron bay.
# Processing Record 15  of Set 1 | hualmay.
# Processing Record 16  of Set 1 | mahon.
# Processing Record 17  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 18  of Set 1 | bredasdorp.
# Processing Record 19  of Set 1 | mitsamiouli.
# Processing Record 20  of Set 1 | torbay.
# Processing Record 21  of Set 1 | castro.
# Processing Record 22  of Set 1 | acapulco.
# Processing Record 23  of Set 1 | lompoc.
# Processing Record 24  of Set 1 | linchuan.
# City not found...skipping linchuan.
# Processing Record 25  of Set 1 | gobabis.
# Processing Record 26  of Set 1 | lalibela.
# Processing Record 27  of Set 1 | hithadhoo.
# Processing Record 28  of Set 1 | cabra.
# Processing Record 29  of Set 1 | coquimbo.
# Processing Record 30  of Set 1 | orangeville.
# Processing Record 31  of Set 1 | aykhal.
# Processing Record 32  of Set 1 | ushuaia.
# Processing Record 33  of Set 1 | ponta do sol.
# Processing Record 34  of Set 1 | albany.
# Processing Record 35  of Set 1 | upernavik.
# Processing Record 36  of Set 1 | pacific grove.
# Processing Record 37  of Set 1 | chuy.
# Processing Record 38  of Set 1 | hambantota.
# Processing Record 39  of Set 1 | tuktoyaktuk.
# Processing Record 40  of Set 1 | bengkulu.
# Processing Record 41  of Set 1 | ocos.
# Processing Record 42  of Set 1 | lata.
# Processing Record 43  of Set 1 | beipiao.
# Processing Record 44  of Set 1 | ust-nera.
# Processing Record 45  of Set 1 | northam.
# Processing Record 46  of Set 1 | same.
# Processing Record 47  of Set 1 | batagay-alyta.
# Processing Record 48  of Set 1 | tari.
# Processing Record 49  of Set 1 | qaanaaq.
# Processing Record 0  of Set 2 | otavi.
# Processing Record 1  of Set 2 | utinga.
# Processing Record 2  of Set 2 | puerto del rosario.
# Processing Record 3  of Set 2 | sampit.
# Processing Record 4  of Set 2 | punta arenas.
# Processing Record 5  of Set 2 | ponta delgada.
# Processing Record 6  of Set 2 | mataura.
# Processing Record 7  of Set 2 | comodoro rivadavia.
# Processing Record 8  of Set 2 | puerto ayora.
# Processing Record 9  of Set 2 | kapaa.
# Processing Record 10  of Set 2 | karpathos.
# Processing Record 11  of Set 2 | balclutha.
# Processing Record 12  of Set 2 | bluff.
# Processing Record 13  of Set 2 | amderma.
# City not found...skipping amderma.
# Processing Record 14  of Set 2 | atuona.
# Processing Record 15  of Set 2 | ancud.
# Processing Record 16  of Set 2 | dwarka.
# Processing Record 17  of Set 2 | launceston.
# Processing Record 18  of Set 2 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 19  of Set 2 | ribeira grande.
# Processing Record 20  of Set 2 | akom.
# Processing Record 21  of Set 2 | avarua.
# Processing Record 22  of Set 2 | urumqi.
# Processing Record 23  of Set 2 | provideniya.
# Processing Record 24  of Set 2 | ajdabiya.
# Processing Record 25  of Set 2 | port lincoln.
# Processing Record 26  of Set 2 | barrow.
# Processing Record 27  of Set 2 | rawson.
# Processing Record 28  of Set 2 | east london.
# Processing Record 29  of Set 2 | chokurdakh.
# Processing Record 30  of Set 2 | atambua.
# Processing Record 31  of Set 2 | taft.
# Processing Record 32  of Set 2 | codrington.
# Processing Record 33  of Set 2 | hami.
# Processing Record 34  of Set 2 | dikson.
# Processing Record 35  of Set 2 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 36  of Set 2 | mahebourg.
# Processing Record 37  of Set 2 | cabo san lucas.
# Processing Record 38  of Set 2 | saint-pierre.
# Processing Record 39  of Set 2 | thompson.
# Processing Record 40  of Set 2 | westport.
# Processing Record 41  of Set 2 | tiksi.
# Processing Record 42  of Set 2 | vila velha.
# Processing Record 43  of Set 2 | souillac.
# Processing Record 44  of Set 2 | peniche.
# Processing Record 45  of Set 2 | arraial do cabo.
# Processing Record 46  of Set 2 | bandarbeyla.
# Processing Record 47  of Set 2 | taitung.
# Processing Record 48  of Set 2 | sevilla.
# Processing Record 49  of Set 2 | padang.
# Processing Record 0  of Set 3 | tasiilaq.
# Processing Record 1  of Set 3 | tsabong.
# Processing Record 2  of Set 3 | faya.
# Processing Record 3  of Set 3 | ostrovnoy.
# Processing Record 4  of Set 3 | jamestown.
# Processing Record 5  of Set 3 | cherskiy.
# Processing Record 6  of Set 3 | guerrero negro.
# Processing Record 7  of Set 3 | bonavista.
# Processing Record 8  of Set 3 | batavia.
# Processing Record 9  of Set 3 | port alfred.
# Processing Record 10  of Set 3 | kismayo.
# Processing Record 11  of Set 3 | basoko.
# Processing Record 12  of Set 3 | goure.
# Processing Record 13  of Set 3 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 14  of Set 3 | namatanai.
# Processing Record 15  of Set 3 | new norfolk.
# Processing Record 16  of Set 3 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 17  of Set 3 | yulara.
# Processing Record 18  of Set 3 | hilo.
# Processing Record 19  of Set 3 | yellowknife.
# Processing Record 20  of Set 3 | butaritari.
# Processing Record 21  of Set 3 | juifang.
# City not found...skipping juifang.
# Processing Record 22  of Set 3 | rongcheng.
# Processing Record 23  of Set 3 | atar.
# Processing Record 24  of Set 3 | thinadhoo.
# Processing Record 25  of Set 3 | khatanga.
# Processing Record 26  of Set 3 | iqaluit.
# Processing Record 27  of Set 3 | avera.
# Processing Record 28  of Set 3 | faanui.
# Processing Record 29  of Set 3 | constitucion.
# Processing Record 30  of Set 3 | katherine.
# Processing Record 31  of Set 3 | narsaq.
# Processing Record 32  of Set 3 | abonnema.
# Processing Record 33  of Set 3 | bethel.
# Processing Record 34  of Set 3 | mayo.
# Processing Record 35  of Set 3 | tukrah.
# Processing Record 36  of Set 3 | okakarara.
# Processing Record 37  of Set 3 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 38  of Set 3 | biak.
# Processing Record 39  of Set 3 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 40  of Set 3 | sola.
# Processing Record 41  of Set 3 | luderitz.
# Processing Record 42  of Set 3 | salalah.
# Processing Record 43  of Set 3 | benemerito de las americas.
# Processing Record 44  of Set 3 | vila.
# Processing Record 45  of Set 3 | bara.
# Processing Record 46  of Set 3 | lavrentiya.
# Processing Record 47  of Set 3 | fort-shevchenko.
# Processing Record 48  of Set 3 | areosa.
# Processing Record 49  of Set 3 | nara.
# Processing Record 0  of Set 4 | lagoa.
# Processing Record 1  of Set 4 | tautira.
# Processing Record 2  of Set 4 | saskylakh.
# Processing Record 3  of Set 4 | port elizabeth.
# Processing Record 4  of Set 4 | berezovyy.
# Processing Record 5  of Set 4 | along.
# Processing Record 6  of Set 4 | urucara.
# Processing Record 7  of Set 4 | vostok.
# Processing Record 8  of Set 4 | saint-philippe.
# Processing Record 9  of Set 4 | sulangan.
# Processing Record 10  of Set 4 | cascais.
# Processing Record 11  of Set 4 | yerbogachen.
# Processing Record 12  of Set 4 | culebra.
# Processing Record 13  of Set 4 | jatai.
# Processing Record 14  of Set 4 | kiruna.
# Processing Record 15  of Set 4 | georgetown.
# Processing Record 16  of Set 4 | fortuna.
# Processing Record 17  of Set 4 | olafsvik.
# Processing Record 18  of Set 4 | creston.
# Processing Record 19  of Set 4 | puerto quijarro.
# Processing Record 20  of Set 4 | nanortalik.
# Processing Record 21  of Set 4 | iskateley.
# Processing Record 22  of Set 4 | hovd.
# Processing Record 23  of Set 4 | mar del plata.
# Processing Record 24  of Set 4 | kavieng.
# Processing Record 25  of Set 4 | port-gentil.
# Processing Record 26  of Set 4 | hermanus.
# Processing Record 27  of Set 4 | saint george.
# Processing Record 28  of Set 4 | harper.
# Processing Record 29  of Set 4 | kisangani.
# Processing Record 30  of Set 4 | salekhard.
# Processing Record 31  of Set 4 | quatre cocos.
# Processing Record 32  of Set 4 | grindavik.
# Processing Record 33  of Set 4 | hobart.
# Processing Record 34  of Set 4 | kutum.
# Processing Record 35  of Set 4 | cumaribo.
# City not found...skipping cumaribo.
# Processing Record 36  of Set 4 | taltal.
# Processing Record 37  of Set 4 | neiafu.
# Processing Record 38  of Set 4 | cidreira.
# Processing Record 39  of Set 4 | taoudenni.
# Processing Record 40  of Set 4 | pisco.
# Processing Record 41  of Set 4 | dedza.
# Processing Record 42  of Set 4 | newberry.
# Processing Record 43  of Set 4 | sao filipe.
# Processing Record 44  of Set 4 | devils lake.
# Processing Record 45  of Set 4 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 46  of Set 4 | margate.
# Processing Record 47  of Set 4 | colares.
# Processing Record 48  of Set 4 | esperance.
# Processing Record 49  of Set 4 | henties bay.
# Processing Record 0  of Set 5 | bijie.
# Processing Record 1  of Set 5 | college.
# Processing Record 2  of Set 5 | rundu.
# Processing Record 3  of Set 5 | nouadhibou.
# Processing Record 4  of Set 5 | weligama.
# Processing Record 5  of Set 5 | san patricio.
# Processing Record 6  of Set 5 | concordia.
# Processing Record 7  of Set 5 | muli.
# Processing Record 8  of Set 5 | khasan.
# Processing Record 9  of Set 5 | dudinka.
# Processing Record 10  of Set 5 | tura.
# Processing Record 11  of Set 5 | flin flon.
# Processing Record 12  of Set 5 | santiago del estero.
# Processing Record 13  of Set 5 | tessaoua.
# Processing Record 14  of Set 5 | dondo.
# Processing Record 15  of Set 5 | athabasca.
# Processing Record 16  of Set 5 | sakakah.
# Processing Record 17  of Set 5 | tshikapa.
# Processing Record 18  of Set 5 | behshahr.
# Processing Record 19  of Set 5 | vardo.
# Processing Record 20  of Set 5 | kloulklubed.
# Processing Record 21  of Set 5 | nguiu.
# City not found...skipping nguiu.
# Processing Record 22  of Set 5 | aksu.
# Processing Record 23  of Set 5 | severo-kurilsk.
# Processing Record 24  of Set 5 | victoria.
# Processing Record 25  of Set 5 | kodiak.
# Processing Record 26  of Set 5 | waipawa.
# Processing Record 27  of Set 5 | guaratinga.
# Processing Record 28  of Set 5 | walvis bay.
# Processing Record 29  of Set 5 | yurya.
# City not found...skipping yurya.
# Processing Record 30  of Set 5 | stanger.
# Processing Record 31  of Set 5 | lorengau.
# Processing Record 32  of Set 5 | jalor.
# Processing Record 33  of Set 5 | blagoyevo.
# Processing Record 34  of Set 5 | cabedelo.
# Processing Record 35  of Set 5 | poum.
# Processing Record 36  of Set 5 | marcona.
# City not found...skipping marcona.
# Processing Record 37  of Set 5 | hofn.
# Processing Record 38  of Set 5 | aklavik.
# Processing Record 39  of Set 5 | rock sound.
# Processing Record 40  of Set 5 | punta alta.
# Processing Record 41  of Set 5 | sao joao da ponte.
# Processing Record 42  of Set 5 | lunglei.
# Processing Record 43  of Set 5 | qeshm.
# Processing Record 44  of Set 5 | swinoujscie.
# Processing Record 45  of Set 5 | olinda.
# Processing Record 46  of Set 5 | saint anthony.
# Processing Record 47  of Set 5 | perth.
# Processing Record 48  of Set 5 | clyde river.
# Processing Record 49  of Set 5 | haapiti.
# Processing Record 0  of Set 6 | honningsvag.
# Processing Record 1  of Set 6 | haines junction.
# Processing Record 2  of Set 6 | kruisfontein.
# Processing Record 3  of Set 6 | fairfield.
# Processing Record 4  of Set 6 | raudeberg.
# Processing Record 5  of Set 6 | shimoda.
# Processing Record 6  of Set 6 | beyla.
# Processing Record 7  of Set 6 | teahupoo.
# Processing Record 8  of Set 6 | canavieiras.
# Processing Record 9  of Set 6 | ahipara.
# Processing Record 10  of Set 6 | marsh harbour.
# Processing Record 11  of Set 6 | maumere.
# Processing Record 12  of Set 6 | sydney.
# Processing Record 13  of Set 6 | canete.
# Processing Record 14  of Set 6 | bereda.
# Processing Record 15  of Set 6 | san andres.
# Processing Record 16  of Set 6 | nerchinskiy zavod.
# Processing Record 17  of Set 6 | caravelas.
# Processing Record 18  of Set 6 | alofi.
# Processing Record 19  of Set 6 | pandan.
# Processing Record 20  of Set 6 | nichinan.
# Processing Record 21  of Set 6 | jahazpur.
# Processing Record 22  of Set 6 | san luis.
# Processing Record 23  of Set 6 | tarko-sale.
# Processing Record 24  of Set 6 | guatire.
# Processing Record 25  of Set 6 | carnarvon.
# Processing Record 26  of Set 6 | lugovoy.
# Processing Record 27  of Set 6 | mmabatho.
# Processing Record 28  of Set 6 | persianovskiy.
# Processing Record 29  of Set 6 | porto novo.
# Processing Record 30  of Set 6 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 31  of Set 6 | isangel.
# Processing Record 32  of Set 6 | kaitangata.
# Processing Record 33  of Set 6 | beringovskiy.
# Processing Record 34  of Set 6 | nalut.
# Processing Record 35  of Set 6 | port moresby.
# Processing Record 36  of Set 6 | mullaitivu.
# City not found...skipping mullaitivu.
# Processing Record 37  of Set 6 | paamiut.
# Processing Record 38  of Set 6 | nome.
# Processing Record 39  of Set 6 | naini tal.
# Processing Record 40  of Set 6 | bowen.
# Processing Record 41  of Set 6 | pimentel.
# Processing Record 42  of Set 6 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 43  of Set 6 | koumra.
# Processing Record 44  of Set 6 | sao joao da barra.
# Processing Record 45  of Set 6 | baykit.
# Processing Record 46  of Set 6 | lebu.
# Processing Record 47  of Set 6 | escanaba.
# Processing Record 48  of Set 6 | cortes.
# Processing Record 49  of Set 6 | pitea.
# Processing Record 0  of Set 7 | petropavlovsk-kamchatskiy.
# Processing Record 1  of Set 7 | emerald.
# Processing Record 2  of Set 7 | saleaula.
# City not found...skipping saleaula.
# Processing Record 3  of Set 7 | ust-maya.
# Processing Record 4  of Set 7 | vao.
# Processing Record 5  of Set 7 | zyryanka.
# Processing Record 6  of Set 7 | portland.
# Processing Record 7  of Set 7 | aden.
# Processing Record 8  of Set 7 | avdiyivka.
# Processing Record 9  of Set 7 | butembo.
# Processing Record 10  of Set 7 | nishihara.
# Processing Record 11  of Set 7 | karauzyak.
# City not found...skipping karauzyak.
# Processing Record 12  of Set 7 | montreal.
# Processing Record 13  of Set 7 | lewisporte.
# Processing Record 14  of Set 7 | xiamen.
# Processing Record 15  of Set 7 | zyukayka.
# Processing Record 16  of Set 7 | srandakan.
# Processing Record 17  of Set 7 | broken hill.
# Processing Record 18  of Set 7 | isla mujeres.
# Processing Record 19  of Set 7 | lubao.
# Processing Record 20  of Set 7 | oltina.
# Processing Record 21  of Set 7 | huarmey.
# Processing Record 22  of Set 7 | montego bay.
# Processing Record 23  of Set 7 | termiz.
# Processing Record 24  of Set 7 | kamenskoye.
# City not found...skipping kamenskoye.
# Processing Record 25  of Set 7 | tezu.
# Processing Record 26  of Set 7 | guilin.
# Processing Record 27  of Set 7 | lolua.
# City not found...skipping lolua.
# Processing Record 28  of Set 7 | falealupo.
# City not found...skipping falealupo.
# Processing Record 29  of Set 7 | garowe.
# Processing Record 30  of Set 7 | isfana.
# Processing Record 31  of Set 7 | sorland.
# Processing Record 32  of Set 7 | pijijiapan.
# Processing Record 33  of Set 7 | san francisco.
# Processing Record 34  of Set 7 | bela vista de goias.
# Processing Record 35  of Set 7 | waterloo.
# Processing Record 36  of Set 7 | voh.
# Processing Record 37  of Set 7 | vestmannaeyjar.
# Processing Record 38  of Set 7 | sokolo.
# Processing Record 39  of Set 7 | paso de los toros.
# Processing Record 40  of Set 7 | banepa.
# Processing Record 41  of Set 7 | sao felix do xingu.
# Processing Record 42  of Set 7 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 43  of Set 7 | smidovich.
# Processing Record 44  of Set 7 | laguna.
# Processing Record 45  of Set 7 | gubkinskiy.
# Processing Record 46  of Set 7 | san cristobal.
# Processing Record 47  of Set 7 | shumskiy.
# Processing Record 48  of Set 7 | mae hong son.
# Processing Record 49  of Set 7 | marienburg.
# Processing Record 0  of Set 8 | mehamn.
# Processing Record 1  of Set 8 | nirasaki.
# Processing Record 2  of Set 8 | kirakira.
# Processing Record 3  of Set 8 | alexandria.
# Processing Record 4  of Set 8 | makaha.
# Processing Record 5  of Set 8 | pangkalanbuun.
# Processing Record 6  of Set 8 | resende.
# Processing Record 7  of Set 8 | uwayl.
# City not found...skipping uwayl.
# Processing Record 8  of Set 8 | nanchang.
# Processing Record 9  of Set 8 | key west.
# Processing Record 10  of Set 8 | satitoa.
# City not found...skipping satitoa.
# Processing Record 11  of Set 8 | geraldton.
# Processing Record 12  of Set 8 | cefalu.
# Processing Record 13  of Set 8 | kongolo.
# Processing Record 14  of Set 8 | miyako.
# Processing Record 15  of Set 8 | muros.
# Processing Record 16  of Set 8 | vila franca do campo.
# Processing Record 17  of Set 8 | posadas.
# Processing Record 18  of Set 8 | mnogovershinnyy.
# Processing Record 19  of Set 8 | saint-augustin.
# Processing Record 20  of Set 8 | ternova.
# Processing Record 21  of Set 8 | vega de alatorre.
# Processing Record 22  of Set 8 | maxixe.
# Processing Record 23  of Set 8 | langfang.
# Processing Record 24  of Set 8 | talnakh.
# Processing Record 25  of Set 8 | saldanha.
# Processing Record 26  of Set 8 | banjarmasin.
# Processing Record 27  of Set 8 | plouzane.
# Processing Record 28  of Set 8 | tabou.
# Processing Record 29  of Set 8 | taybad.
# Processing Record 30  of Set 8 | saint marys.
# Processing Record 31  of Set 8 | san carlos de bariloche.
# Processing Record 32  of Set 8 | namibe.
# Processing Record 33  of Set 8 | balsas.
# Processing Record 34  of Set 8 | ardrishaig.
# Processing Record 35  of Set 8 | betsiamites.
# Processing Record 36  of Set 8 | bandundu.
# Processing Record 37  of Set 8 | fare.
# Processing Record 38  of Set 8 | camacha.
# Processing Record 39  of Set 8 | san quintin.
# Processing Record 40  of Set 8 | jalu.
# Processing Record 41  of Set 8 | longyearbyen.
# Processing Record 42  of Set 8 | bambous virieux.
# Processing Record 43  of Set 8 | stephenville.
# Processing Record 44  of Set 8 | jiddah.
# City not found...skipping jiddah.
# Processing Record 45  of Set 8 | contamana.
# Processing Record 46  of Set 8 | bonoua.
# Processing Record 47  of Set 8 | uruzgan.
# Processing Record 48  of Set 8 | disa.
# Processing Record 49  of Set 8 | los llanos de aridane.
# Processing Record 0  of Set 9 | rassvet.
# Processing Record 1  of Set 9 | boa vista.
# Processing Record 2  of Set 9 | andros town.
# Processing Record 3  of Set 9 | prince rupert.
# Processing Record 4  of Set 9 | totoro.
# Processing Record 5  of Set 9 | ayan.
# Processing Record 6  of Set 9 | pathalgaon.
# Processing Record 7  of Set 9 | maralal.
# Processing Record 8  of Set 9 | pokhara.
# Processing Record 9  of Set 9 | bathsheba.
# Processing Record 10  of Set 9 | itaituba.
# Processing Record 11  of Set 9 | zachagansk.
# City not found...skipping zachagansk.
# Processing Record 12  of Set 9 | bud.
# Processing Record 13  of Set 9 | kaiyuan.
# Processing Record 14  of Set 9 | te anau.
# Processing Record 15  of Set 9 | yaan.
# Processing Record 16  of Set 9 | vilyuysk.
# Processing Record 17  of Set 9 | seshcha.
# Processing Record 18  of Set 9 | asau.
# Processing Record 19  of Set 9 | sarankhola.
# Processing Record 20  of Set 9 | slave lake.
# Processing Record 21  of Set 9 | hamilton.
# Processing Record 22  of Set 9 | narrabri.
# Processing Record 23  of Set 9 | bolshiye berezniki.
# City not found...skipping bolshiye berezniki.
# Processing Record 24  of Set 9 | kapit.
# Processing Record 25  of Set 9 | pedernales.
# Processing Record 26  of Set 9 | biu.
# Processing Record 27  of Set 9 | adolfo lopez mateos.
# Processing Record 28  of Set 9 | mizan teferi.
# Processing Record 29  of Set 9 | sambava.
# Processing Record 30  of Set 9 | rabo de peixe.
# Processing Record 31  of Set 9 | kinel-cherkassy.
# Processing Record 32  of Set 9 | tucurui.
# Processing Record 33  of Set 9 | almetyevsk.
# Processing Record 34  of Set 9 | yerkoy.
# Processing Record 35  of Set 9 | flinders.
# Processing Record 36  of Set 9 | ulyanovka.
# Processing Record 37  of Set 9 | long beach.
# Processing Record 38  of Set 9 | dicabisagan.
# Processing Record 39  of Set 9 | puerto colombia.
# Processing Record 40  of Set 9 | cedar rapids.
# Processing Record 41  of Set 9 | viedma.
# Processing Record 42  of Set 9 | rockwall.
# Processing Record 43  of Set 9 | adrar.
# Processing Record 44  of Set 9 | nizhniy kuranakh.
# Processing Record 45  of Set 9 | berlevag.
# Processing Record 46  of Set 9 | somogyvar.
# Processing Record 47  of Set 9 | muravlenko.
# Processing Record 48  of Set 9 | richards bay.
# Processing Record 49  of Set 9 | namuac.
# Processing Record 0  of Set 10 | anadyr.
# Processing Record 1  of Set 10 | susurluk.
# Processing Record 2  of Set 10 | moree.
# Processing Record 3  of Set 10 | saurimo.
# Processing Record 4  of Set 10 | kropotkin.
# Processing Record 5  of Set 10 | koulikoro.
# Processing Record 6  of Set 10 | coihaique.
# Processing Record 7  of Set 10 | fuerte.
# Processing Record 8  of Set 10 | puro.
# Processing Record 9  of Set 10 | sioux lookout.
# Processing Record 10  of Set 10 | natal.
# Processing Record 11  of Set 10 | meulaboh.
# Processing Record 12  of Set 10 | crab hill.
# City not found...skipping crab hill.
# Processing Record 13  of Set 10 | dong hoi.
# Processing Record 14  of Set 10 | chifeng.
# Processing Record 15  of Set 10 | drovyanaya.
# Processing Record 16  of Set 10 | norman wells.
# Processing Record 17  of Set 10 | guhagar.
# Processing Record 18  of Set 10 | ginir.
# Processing Record 19  of Set 10 | aksarka.
# Processing Record 20  of Set 10 | pelym.
# Processing Record 21  of Set 10 | tubruq.
# City not found...skipping tubruq.
# Processing Record 22  of Set 10 | seymchan.
# Processing Record 23  of Set 10 | komsomolskiy.
# Processing Record 24  of Set 10 | rocha.
# Processing Record 25  of Set 10 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 26  of Set 10 | gondanglegi.
# Processing Record 27  of Set 10 | munai.
# Processing Record 28  of Set 10 | rafraf.
# Processing Record 29  of Set 10 | nelson bay.
# Processing Record 30  of Set 10 | guozhen.
# Processing Record 31  of Set 10 | bartica.
# Processing Record 32  of Set 10 | oranjemund.
# Processing Record 33  of Set 10 | araouane.
# Processing Record 34  of Set 10 | vondrozo.
# Processing Record 35  of Set 10 | phangnga.
# Processing Record 36  of Set 10 | ondorhaan.
# City not found...skipping ondorhaan.
# Processing Record 37  of Set 10 | socorro.
# Processing Record 38  of Set 10 | egvekinot.
# Processing Record 39  of Set 10 | kajaani.
# Processing Record 40  of Set 10 | iglino.
# Processing Record 41  of Set 10 | yambio.
# Processing Record 42  of Set 10 | jizan.
# Processing Record 43  of Set 10 | u thong.
# Processing Record 44  of Set 10 | boralday.
# Processing Record 45  of Set 10 | high level.
# Processing Record 46  of Set 10 | todos santos.
# Processing Record 47  of Set 10 | luwuk.
# Processing Record 48  of Set 10 | bobcaygeon.
# Processing Record 49  of Set 10 | novobirilyussy.
# Processing Record 0  of Set 11 | chagda.
# City not found...skipping chagda.
# Processing Record 1  of Set 11 | sur.
# Processing Record 2  of Set 11 | coruripe.
# Processing Record 3  of Set 11 | kokkinion.
# City not found...skipping kokkinion.
# Processing Record 4  of Set 11 | cap malheureux.
# Processing Record 5  of Set 11 | kahului.
# Processing Record 6  of Set 11 | bundaberg.
# Processing Record 7  of Set 11 | muisne.
# Processing Record 8  of Set 11 | saryagash.
# Processing Record 9  of Set 11 | durban.
# Processing Record 10  of Set 11 | warqla.
# City not found...skipping warqla.
# Processing Record 11  of Set 11 | hefei.
# Processing Record 12  of Set 11 | mookane.
# Processing Record 13  of Set 11 | kawana waters.
# City not found...skipping kawana waters.
# Processing Record 14  of Set 11 | grand island.
# Processing Record 15  of Set 11 | matara.
# Processing Record 16  of Set 11 | baruun-urt.
# Processing Record 17  of Set 11 | raychikhinsk.
# Processing Record 18  of Set 11 | ilulissat.
# Processing Record 19  of Set 11 | phan thiet.
# Processing Record 20  of Set 11 | pula.
# Processing Record 21  of Set 11 | vanavara.
# Processing Record 22  of Set 11 | balkhash.
# Processing Record 23  of Set 11 | nioro.
# Processing Record 24  of Set 11 | indramayu.
# Processing Record 25  of Set 11 | broome.
# Processing Record 26  of Set 11 | pangnirtung.
# Processing Record 27  of Set 11 | yining.
# Processing Record 28  of Set 11 | bama.
# Processing Record 29  of Set 11 | belmonte.
# Processing Record 30  of Set 11 | charlestown.
# Processing Record 31  of Set 11 | kaeo.
# Processing Record 32  of Set 11 | tokur.
# Processing Record 33  of Set 11 | piacabucu.
# Processing Record 34  of Set 11 | pevek.
# Processing Record 35  of Set 11 | dunda.
# Processing Record 36  of Set 11 | magui.
# City not found...skipping magui.
# Processing Record 37  of Set 11 | babanusah.
# City not found...skipping babanusah.
# Processing Record 38  of Set 11 | tevriz.
# Processing Record 39  of Set 11 | kushmurun.
# Processing Record 40  of Set 11 | ambon.
# Processing Record 41  of Set 11 | kupang.
# Processing Record 42  of Set 11 | hoa binh.
# Processing Record 43  of Set 11 | bardiyah.
# Processing Record 44  of Set 11 | labuhan.
# Processing Record 45  of Set 11 | ilheus.
# Processing Record 46  of Set 11 | ibague.
# Processing Record 47  of Set 11 | cockburn harbour.
# City not found...skipping cockburn harbour.
# Processing Record 48  of Set 11 | haysville.
# Processing Record 49  of Set 11 | wesselsbron.
# Processing Record 0  of Set 12 | ouesso.
# Processing Record 1  of Set 12 | dargaville.
# Processing Record 2  of Set 12 | dolbeau.
# City not found...skipping dolbeau.
# Processing Record 3  of Set 12 | coos bay.
# Processing Record 4  of Set 12 | hasaki.
# Processing Record 5  of Set 12 | lev tolstoy.
# Processing Record 6  of Set 12 | lethem.
# Processing Record 7  of Set 12 | teya.
# Processing Record 8  of Set 12 | belyy yar.
# Processing Record 9  of Set 12 | ngunguru.
# Processing Record 10  of Set 12 | natchitoches.
# Processing Record 11  of Set 12 | saint-leu.
# Processing Record 12  of Set 12 | bairiki.
# Processing Record 13  of Set 12 | denpasar.
# Processing Record 14  of Set 12 | sorkjosen.
# Processing Record 15  of Set 12 | malanday.
# Processing Record 16  of Set 12 | horasan.
# Processing Record 17  of Set 12 | ashqelon.
# Processing Record 18  of Set 12 | tatarsk.
# Processing Record 19  of Set 12 | adamovka.
# Processing Record 20  of Set 12 | yokadouma.
# Processing Record 21  of Set 12 | kiama.
# Processing Record 22  of Set 12 | benguela.
# Processing Record 23  of Set 12 | nurota.
# Processing Record 24  of Set 12 | bonthe.
# Processing Record 25  of Set 12 | xiaoweizhai.
# Processing Record 26  of Set 12 | kumluca.
# Processing Record 27  of Set 12 | wanaka.
# Processing Record 28  of Set 12 | sao gabriel da cachoeira.
# Processing Record 29  of Set 12 | erenhot.
# Processing Record 30  of Set 12 | shizunai.
# Processing Record 31  of Set 12 | sfantu gheorghe.
# Processing Record 32  of Set 12 | chicama.
# Processing Record 33  of Set 12 | wuzhou.
# Processing Record 34  of Set 12 | takoradi.
# Processing Record 35  of Set 12 | kungurtug.
# Processing Record 36  of Set 12 | iquique.
# Processing Record 37  of Set 12 | freeport.
# Processing Record 38  of Set 12 | chara.
# Processing Record 39  of Set 12 | sovetskiy.
# Processing Record 40  of Set 12 | rovira.
# Processing Record 41  of Set 12 | west monroe.
# Processing Record 42  of Set 12 | leningradskiy.
# Processing Record 43  of Set 12 | laibin.
# Processing Record 44  of Set 12 | xai-xai.
# Processing Record 45  of Set 12 | gat.
# Processing Record 46  of Set 12 | ilhabela.
# Processing Record 47  of Set 12 | kampene.
# Processing Record 48  of Set 12 | oistins.
# Processing Record 49  of Set 12 | buenos aires.
# Processing Record 0  of Set 13 | tadine.
# Processing Record 1  of Set 13 | suoyarvi.
# Processing Record 2  of Set 13 | obluche.
# City not found...skipping obluche.
# Processing Record 3  of Set 13 | sembe.
# Processing Record 4  of Set 13 | savasleyka.
# Processing Record 5  of Set 13 | helong.
# Processing Record 6  of Set 13 | ivankiv.
# Processing Record 7  of Set 13 | nemuro.
# Processing Record 8  of Set 13 | houma.
# Processing Record 9  of Set 13 | marawi.
# Processing Record 10  of Set 13 | barabai.
# Processing Record 11  of Set 13 | zhezkazgan.
# Processing Record 12  of Set 13 | husavik.
# Processing Record 13  of Set 13 | nerang.
# Processing Record 14  of Set 13 | kamiiso.
# Processing Record 15  of Set 13 | golkoy.
# Processing Record 16  of Set 13 | troitsko-pechorsk.
# Processing Record 17  of Set 13 | saryshagan.
# City not found...skipping saryshagan.
# Processing Record 18  of Set 13 | mogadishu.
# Processing Record 19  of Set 13 | nogales.
# Processing Record 20  of Set 13 | gambela.
# Processing Record 21  of Set 13 | vite.
# Processing Record 22  of Set 13 | la romana.
# Processing Record 23  of Set 13 | ao luk.
# City not found...skipping ao luk.
# Processing Record 24  of Set 13 | san vicente.
# Processing Record 25  of Set 13 | inta.
# Processing Record 26  of Set 13 | praia da vitoria.
# Processing Record 27  of Set 13 | khairpur nathan shah.
# Processing Record 28  of Set 13 | katsuura.
# Processing Record 29  of Set 13 | linxia.
# Processing Record 30  of Set 13 | formosa do rio preto.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_df.dtypes
# Out:
# City                 object
# Country              object
# Latitude            float64
# Longitude           float64
# Cloudiness (%)      float64
# Humidity (%)        float64
# Max Temp (F)        float64
# Wind Speed (mph)    float64
# Date                float64
# dtype: object

# %%
# Convert data strings to float
weather_df["Cloudiness (%)"] = pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
weather_df["Humidity (%)"] = pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
weather_df["Latitude"] = pd.to_numeric(weather_df["Latitude"]).astype(float)
weather_df["Longitude"] = pd.to_numeric(weather_df["Longitude"]).astype(float)
weather_df["Max Temp (F)"] = pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
weather_df["Wind Speed (mph)"] = pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df["Date"] = pd.to_numeric(weather_df["Date"]).astype(float)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")
weather_df.head()
# Out:
#           City Country  Latitude  Longitude  Cloudiness (%)  Humidity (%)  \
# 0    tuatapere      NZ  -46.1333   167.6833            25.0          88.0
# 1    manokwari      ID   -0.8667   134.0833            61.0          75.0
# 2        sitka      US   57.0531  -135.3300            75.0          76.0
# 3  butterworth      MY    5.3991   100.3638            20.0          70.0
# 4        vaini      TO  -21.2000  -175.2000           100.0          59.0
#
#    Max Temp (F)  Wind Speed (mph)          Date
# 0         48.18              2.84  1.652595e+09
# 1         82.96              3.80  1.652595e+09
# 2         46.29              5.75  1.652595e+09
# 3         91.44             10.36  1.652595e+09
# 4         73.92             14.36  1.652595e+09

# %%
len(weather_df)
# Out:
# 631

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.drop(weather_df[weather_df['Humidity (%)'] > 100].index, inplace = True)
weather_df
# Out:
#                      City Country  Latitude  Longitude  Cloudiness (%)  \
# 0               tuatapere      NZ  -46.1333   167.6833            25.0
# 1               manokwari      ID   -0.8667   134.0833            61.0
# 2                   sitka      US   57.0531  -135.3300            75.0
# 3             butterworth      MY    5.3991   100.3638            20.0
# 4                   vaini      TO  -21.2000  -175.2000           100.0
# ..                    ...     ...       ...        ...             ...
# 626      praia da vitoria      PT   38.7333   -27.0667            40.0
# 627  khairpur nathan shah      PK   27.0936    67.7337             0.0
# 628              katsuura      JP   35.1333   140.3000           100.0
# 629                linxia      CN   35.6003   103.2064            49.0
# 630  formosa do rio preto      BR  -11.0483   -45.1931           100.0
#
#      Humidity (%)  Max Temp (F)  Wind Speed (mph)          Date
# 0            88.0         48.18              2.84  1.652595e+09
# 1            75.0         82.96              3.80  1.652595e+09
# 2            76.0         46.29              5.75  1.652595e+09
# 3            70.0         91.44             10.36  1.652595e+09
# 4            59.0         73.92             14.36  1.652595e+09
# ..            ...           ...               ...           ...
# 626          82.0         57.76             15.23  1.652595e+09
# 627           9.0        109.38              3.76  1.652595e+09
# 628          73.0         63.50             16.20  1.652595e+09
# 629          40.0         57.65              8.14  1.652595e+09
# 630          59.0         71.80              3.40  1.652595e+09
#
# [631 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Max Temp (F)"],edgecolors="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("fig1.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity (%)"],edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.savefig("fig2.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness (%)"],edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("fig3.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed (mph)"],edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.savefig("fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude'])
y_values = pd.to_numeric(northern_df['Max Temp (F)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.savefig("fig5.png")
plt.show()
# Out:
# Regression line equation is: y = -0.72x + 90.29
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude'])
y_values = pd.to_numeric(southern_df['Max Temp (F)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.savefig("fig6.png")
plt.show()
# Out:
# Regression line equation is: y = 0.76x + 84.91
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude'])
y_values = pd.to_numeric(northern_df['Humidity (%)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig7.png")
plt.show()
# Out:
# Regression line equation is: y = 0.11x + 64.71
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude'])
y_values = pd.to_numeric(southern_df['Humidity (%)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig8.png")
plt.show()
# Out:
# Regression line equation is: y = -0.09x + 72.72
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude'])
y_values = pd.to_numeric(northern_df['Cloudiness (%)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig9.png")
plt.show()
# Out:
# Regression line equation is: y = 0.23x + 54.72
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude'])
y_values = pd.to_numeric(southern_df['Cloudiness (%)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig10.png")
plt.show()
# Out:
# Regression line equation is: y = 0.7x + 67.09
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude'])
y_values = pd.to_numeric(northern_df['Wind Speed (mph)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig11.png")
plt.show()
# Out:
# Regression line equation is: y = 0.04x + 6.68
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude'])
y_values = pd.to_numeric(southern_df['Wind Speed (mph)'])
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print("The regression does not display much of a correlation between the data sets.")
plt.savefig("fig12.png")
plt.show()
# Out:
# Regression line equation is: y = -0.07x + 5.4
# The regression does not display much of a correlation between the data sets.
